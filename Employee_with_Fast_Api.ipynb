# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Employee.csv')
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %%
cols = ['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
       'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot']

# %%
df.duplicated().sum()
# Out:
# np.int64(1889)

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.shape
# Out:
# (4653, 9)

# %%
for i in cols :
  print(f'NUmber of values of {i} is {df[i].nunique()}')
  print(df[i].unique())
  print('-'*30)
# Out:
# NUmber of values of Education is 3
# ['Bachelors' 'Masters' 'PHD']
# ------------------------------
# NUmber of values of JoiningYear is 7
# [2017 2013 2014 2016 2015 2012 2018]
# ------------------------------
# NUmber of values of City is 3
# ['Bangalore' 'Pune' 'New Delhi']
# ------------------------------
# NUmber of values of PaymentTier is 3
# [3 1 2]
# ------------------------------
# NUmber of values of Age is 20
# [34 28 38 27 24 22 23 37 32 39 29 30 36 31 25 26 40 35 33 41]
# ------------------------------
# NUmber of values of Gender is 2
# ['Male' 'Female']
# ------------------------------
# NUmber of values of EverBenched is 2
# ['No' 'Yes']
# ------------------------------
# NUmber of values of ExperienceInCurrentDomain is 8
# [0 3 2 5 1 4 7 6]
# ------------------------------
# NUmber of values of LeaveOrNot is 2
# [0 1]
# ------------------------------

# %%
df.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
sns.displot(x='Age',data=df,kde=True)

# %%
sns.countplot(x='Education',data=df,palette='mako')
# Out:
# <ipython-input-12-35bae719589a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Education',data=df,palette='mako')
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Education',hue='City',data=df,palette='mako')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Education',hue='PaymentTier',data=df,palette='dark')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Education',hue='Gender',data=df,palette='mako')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Education',hue='EverBenched',data=df,palette='mako')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Education',hue='ExperienceInCurrentDomain',data=df,palette='bright')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='JoiningYear',data=df,palette='pastel')
# Out:
# <ipython-input-18-e07daf6466da>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='JoiningYear',data=df,palette='pastel')
# <Axes: xlabel='JoiningYear', ylabel='count'>

# %%
sns.countplot(x='JoiningYear',hue='City',data=df,palette='pastel')
# Out:
# <Axes: xlabel='JoiningYear', ylabel='count'>

# %%
sns.countplot(x='JoiningYear',hue='PaymentTier',data=df,palette='pastel')
# Out:
# <Axes: xlabel='JoiningYear', ylabel='count'>

# %%
sns.boxplot(x='JoiningYear',y='Age',data=df,palette='pastel')
# Out:
# <ipython-input-21-b6e3db73eee1>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='JoiningYear',y='Age',data=df,palette='pastel')
# <Axes: xlabel='JoiningYear', ylabel='Age'>

# %%
sns.countplot(x='JoiningYear',hue='Gender',data=df,palette='pastel')
# Out:
# <Axes: xlabel='JoiningYear', ylabel='count'>

# %%
sns.countplot(x='JoiningYear',hue='EverBenched',data=df,palette='pastel')
# Out:
# <Axes: xlabel='JoiningYear', ylabel='count'>

# %%
sns.countplot(x='JoiningYear',hue='ExperienceInCurrentDomain',data=df,palette='pastel')
# Out:
# <Axes: xlabel='JoiningYear', ylabel='count'>

# %%
cols = ['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
       'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot']

# %%
sns.countplot(x='PaymentTier',data=df,palette='deep')
# Out:
# <ipython-input-26-699f2c1493f5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='PaymentTier',data=df,palette='deep')
# <Axes: xlabel='PaymentTier', ylabel='count'>

# %%
sns.boxplot(x='PaymentTier',y='Age',hue='Gender',data=df,palette='deep')
# Out:
# <Axes: xlabel='PaymentTier', ylabel='Age'>

# %%
sns.countplot(x='PaymentTier',hue='EverBenched',data=df,palette='deep')
# Out:
# <Axes: xlabel='PaymentTier', ylabel='count'>

# %%
sns.countplot(x='PaymentTier',hue='ExperienceInCurrentDomain',data=df,palette='deep')
# Out:
# <Axes: xlabel='PaymentTier', ylabel='count'>

# %%
df.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier

# %%
x = df.drop('LeaveOrNot', axis=1)
y = df['LeaveOrNot']

# %%
x
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 4648    0
# 4649    1
# 4650    1
# 4651    0
# 4652    0
# Name: LeaveOrNot, Length: 4653, dtype: int64

# %%
numeric_features = ['JoiningYear', 'PaymentTier','Age','ExperienceInCurrentDomain']
categorical_features = ['Education', 'City','Gender','EverBenched']

numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder()

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', KNeighborsClassifier())
])

# %%
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['JoiningYear', 'PaymentTier',
#                                                    'Age',
#                                                    'ExperienceInCurrentDomain']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['Education', 'City',
#                                                    'Gender',
#                                                    'EverBenched'])])),
#                 ('classifier', KNeighborsClassifier())])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['JoiningYear', 'PaymentTier',
#                                                    'Age',
#                                                    'ExperienceInCurrentDomain']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['Education', 'City',
#                                                    'Gender',
#                                                    'EverBenched'])])),
#                 ('classifier', KNeighborsClassifier())])

# %%
from sklearn.metrics import accuracy_score , confusion_matrix , precision_score,recall_score , f1_score ,fbeta_score ,classification_report

# %%
y_pred = model.predict(x_test)

# %%
print(f'Traning Accuracy : {accuracy_score(y_train,model.predict(x_train))}')
print(f'Testing Accuracy : {accuracy_score(y_test,y_pred)}')
# Out:
# Traning Accuracy : 0.8631478385478863
# Testing Accuracy : 0.8218884120171673

# %%
import joblib

joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']
